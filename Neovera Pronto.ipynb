# %%
import pyautogui
import pyperclip
import time

# %%
#pyautogui.PAUSE = 10
#pyautogui.position()

# %% [markdown]
# # Neovera Abertura de Ordem de Serviço

# %%
pyautogui.PAUSE = 4
#Abrir navegador
pyautogui.hotkey("ctrl", "t")
#Abrir Neovero
pyperclip.copy("https://impareh.neovero.com/")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
pyperclip.copy("caleb.silva")
pyautogui.hotkey ("ctrl", "v")
pyautogui.press ("tab")
pyautogui.write ("chniteroi")
pyautogui.hotkey("tab", "enter")

#Fechar a Janela
time.sleep(10)
pyautogui.click(x=1115, y=216)


#pyautogui.position (x=679, y=425)
#Anotar numero da OS
#Enviar para o e-mail.

# %%
#Abrir ordem de serviço rapido
time.sleep(3)
pyautogui.click(x=118, y=460)
time.sleep(5)

# %% [markdown]
# # OS da Cobertura(Reservatório)

# %%
#Cobertura
pyautogui.PAUSE = 1
time.sleep(2)
pyperclip.copy("6225")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
time.sleep(3)
pyautogui.click(x=484, y=389)
pyautogui.click(x=449, y=387)
#Mudar hora
pyperclip.copy("0700")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.click(x=686, y=388)
pyautogui.click(x=373, y=431)
#Mudar tipos de Ordem
pyperclip.copy("HIDR")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Ordem para preventiva é 2
pyperclip.copy("2")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Ordem para Caleb
pyperclip.copy("65053")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Abrir OS Responsalvel Romulo
pyperclip.copy("4419")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyperclip.copy("Fazer inspeção no Reservatório")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Fazer OS Para Reservatório
pyperclip.copy("215")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Abrir para inspeção
pyautogui.press("i")
pyautogui.press("i")
#
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Mudar Hora de Termino
pyperclip.copy("0720")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.click(x=662, y=434)
#
pyautogui.press ("tab")
pyperclip.copy("65053")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.press ("tab")
pyperclip.copy("8822")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.click(x=1078, y=644)
# Out:
# KeyboardInterrupt

# %% [markdown]
# # OS da Cobertura (Boiler)

# %%
#Cobertura

pyautogui.PAUSE = 1
time.sleep(2)
pyautogui.click(x=881, y=298)
pyautogui.click(x=403, y=267)
pyperclip.copy("6225")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
time.sleep(3)
pyautogui.click(x=484, y=389)
pyautogui.click(x=449, y=387)
#Mudar hora
pyperclip.copy("0720")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.click(x=683, y=390)
pyautogui.click(x=379, y=431)
#Mudar tipos de Ordem
#pyperclip.copy("hid")
#pyautogui.hotkey("ctrl", "v")
#pyautogui.press ("tab")
#pyautogui.press ("tab")
#Ordem para inspeção é 2
pyautogui.click(x=643, y=430)
pyperclip.copy("2")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Ordem para Caleb
pyperclip.copy("65053")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Abrir OS Responsalvel Fernando
pyperclip.copy("4419")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyperclip.copy("Fazer inspeção No Boiler")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Fazer OS Para Reservatório
pyperclip.copy("215")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Abrir para inspeção
pyautogui.press("i")
pyautogui.press("i")
#
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Mudar Hora de Termino
pyperclip.copy("0730")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.click(x=664, y=432)
#
pyautogui.press ("tab")
pyperclip.copy("65053")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.press ("tab")
pyperclip.copy("8822")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.click(x=1068, y=644)

# %%
#Fechar a ordem para abrir uma nova, para O TIPO DE ORDEM
pyautogui.PAUSE = 2
pyautogui.click(x=881, y=298)
pyautogui.click(x=1075, y=223)
pyautogui.click(x=118, y=460)

# %% [markdown]
# OS da Cobertura (Nobreak)

# %%
#Cobertura

pyautogui.PAUSE = 1
time.sleep(2)
pyautogui.click(x=403, y=267)
pyperclip.copy("6225")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
time.sleep(3)
pyautogui.click(x=484, y=389)
pyautogui.click(x=449, y=387)
#Mudar hora
pyperclip.copy("0730")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.click(x=683, y=390)
pyautogui.click(x=379, y=431)
#Mudar tipos de Ordem
pyperclip.copy("ele")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Ordem para inspeção é 2
pyautogui.click(x=643, y=430)
pyperclip.copy("2")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Ordem para Caleb
pyperclip.copy("65053")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Abrir OS Responsalvel Fernando
pyperclip.copy("4419")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyperclip.copy("Fazer inspeção nos Nobreaks")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Fazer OS Para Nobreak
pyperclip.copy("175")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Abrir para inspeção
pyautogui.press("i")
pyautogui.press("i")
#
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Mudar Hora de Termino
pyperclip.copy("0740")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.click(x=664, y=432)
#
pyautogui.press ("tab")
pyperclip.copy("65053")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.press ("tab")
pyperclip.copy("8822")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.click(x=1068, y=644)

# %%
#Fechar a ordem para abrir uma nova, para O TIPO DE ORDEM
pyautogui.PAUSE = 2
pyautogui.click(x=881, y=298)
pyautogui.click(x=1075, y=223)
pyautogui.click(x=118, y=460)

# %% [markdown]
# Os de Cilindros de O2

# %%
#Cilindro Neuro intensiva

pyautogui.PAUSE = 1
time.sleep(2)
pyautogui.click(x=881, y=298)
pyautogui.click(x=403, y=267)
pyperclip.copy("010201140002")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
time.sleep(3)
pyautogui.click(x=484, y=389)
pyautogui.click(x=449, y=387)
#Mudar hora
pyperclip.copy("0740")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.click(x=683, y=390)
pyautogui.click(x=379, y=431)
#Mudar tipos de Ordem
pyperclip.copy("gas")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Ordem para inspeção é 2
pyperclip.copy("2")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Ordem para Caleb
pyperclip.copy("65053")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Abrir OS Responsalvel Fernando
pyperclip.copy("4419")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyperclip.copy("Fazer inspeção dos cilidros de O2")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Fazer OS Para Cilindros O2
pyperclip.copy("7")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Abrir para inspeção
pyautogui.press("i")
pyautogui.press("i")
#
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Mudar Hora de Termino
pyperclip.copy("0750")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.click(x=664, y=432)
#
pyautogui.press ("tab")
pyperclip.copy("65053")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.press ("tab")
pyperclip.copy("8822")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.click(x=1068, y=644)

# %%
#Fechar a ordem para abrir uma nova, para O TIPO DE ORDEM
pyautogui.PAUSE = 2
pyautogui.click(x=881, y=298)
pyautogui.click(x=1075, y=223)
pyautogui.click(x=118, y=460)

# %%
#Cilindro Pos Operatorio

pyautogui.PAUSE = 1
time.sleep(2)
pyautogui.click(x=881, y=298)
pyautogui.click(x=403, y=267)
pyperclip.copy("010201250016")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
time.sleep(3)
pyautogui.click(x=484, y=389)
pyautogui.click(x=449, y=387)
#Mudar hora
pyperclip.copy("0750")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.click(x=683, y=390)
pyautogui.click(x=379, y=431)
#Mudar tipos de Ordem
pyperclip.copy("gas")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Ordem para inspeção é 2
pyperclip.copy("2")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Ordem para Caleb
pyperclip.copy("65053")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Abrir OS Responsalvel Fernando
pyperclip.copy("4419")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyperclip.copy("Fazer inspeção dos cilidros de O2")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Fazer OS Para Cilindros O2
pyperclip.copy("7")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Abrir para inspeção
pyautogui.press("i")
pyautogui.press("i")
#
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Mudar Hora de Termino
pyperclip.copy("0800")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.click(x=664, y=432)
#
pyautogui.press ("tab")
pyperclip.copy("65053")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.press ("tab")
pyperclip.copy("8822")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.click(x=1068, y=644)

# %%
#Fechar a ordem para abrir uma nova, para O TIPO DE ORDEM
pyautogui.PAUSE = 2
pyautogui.click(x=881, y=298)
pyautogui.click(x=1075, y=223)
pyautogui.click(x=118, y=460)

# %%
#Cilindro CTI

pyautogui.PAUSE = 1
time.sleep(2)
pyautogui.click(x=881, y=298)
pyautogui.click(x=403, y=267)
pyperclip.copy("010200120001")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
time.sleep(3)
pyautogui.click(x=484, y=389)
pyautogui.click(x=449, y=387)
#Mudar hora
pyperclip.copy("0800")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.click(x=683, y=390)
pyautogui.click(x=379, y=431)
#Mudar tipos de Ordem
pyperclip.copy("gas")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Ordem para inspeção é 2
pyperclip.copy("2")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Ordem para Caleb
pyperclip.copy("65053")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Abrir OS Responsalvel Fernando
pyperclip.copy("4419")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyperclip.copy("Fazer inspeção dos cilidros de O2")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Fazer OS Para Cilindros O2
pyperclip.copy("7")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Abrir para inspeção
pyautogui.press("i")
pyautogui.press("i")
#
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Mudar Hora de Termino
pyperclip.copy("0810")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.click(x=664, y=432)
#
pyautogui.press ("tab")
pyperclip.copy("65053")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.press ("tab")
pyperclip.copy("8822")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.click(x=1068, y=644)

# %%
#Cilindro Cardio

pyautogui.PAUSE = 1
time.sleep(2)
pyautogui.click(x=881, y=298)
pyautogui.click(x=403, y=267)
pyperclip.copy("010200320001")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
time.sleep(3)
pyautogui.click(x=484, y=389)
pyautogui.click(x=449, y=387)
#Mudar hora
pyperclip.copy("0810")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.click(x=683, y=390)
pyautogui.click(x=379, y=431)
#Mudar tipos de Ordem
pyperclip.copy("gas")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Ordem para inspeção é 2
pyperclip.copy("2")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Ordem para Caleb
pyperclip.copy("65053")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Abrir OS Responsalvel Fernando
pyperclip.copy("4419")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyperclip.copy("Fazer inspeção dos cilidros de O2")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Fazer OS Para Cilindros O2
pyperclip.copy("7")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Abrir para inspeção
pyautogui.press("i")
pyautogui.press("i")
#
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Mudar Hora de Termino
pyperclip.copy("0820")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.click(x=664, y=432)
#
pyautogui.press ("tab")
pyperclip.copy("65053")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.press ("tab")
pyperclip.copy("8822")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.click(x=1068, y=644)

# %%
#Cilindro Cardio

pyautogui.PAUSE = 1
time.sleep(2)
pyautogui.click(x=881, y=298)
pyautogui.click(x=403, y=267)
pyperclip.copy("010200320001")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
time.sleep(3)
pyautogui.click(x=484, y=389)
pyautogui.click(x=449, y=387)
#Mudar hora
pyperclip.copy("0820")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.click(x=683, y=390)
pyautogui.click(x=379, y=431)
#Mudar tipos de Ordem
pyperclip.copy("gas")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Ordem para inspeção é 2
pyperclip.copy("2")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Ordem para Caleb
pyperclip.copy("65053")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Abrir OS Responsalvel Fernando
pyperclip.copy("4419")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyperclip.copy("Fazer inspeção dos cilindros de O2")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Fazer OS Para Cilindros O2
pyperclip.copy("7")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Abrir para inspeção
pyautogui.press("i")
pyautogui.press("i")
#
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Mudar Hora de Termino
pyperclip.copy("0830")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.click(x=664, y=432)
#
pyautogui.press ("tab")
pyperclip.copy("65053")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.press ("tab")
pyperclip.copy("8822")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.click(x=1068, y=644)

# %%
#Cilindro CTI Pediatrico

pyautogui.PAUSE = 1
time.sleep(2)
pyautogui.click(x=881, y=298)
pyautogui.click(x=403, y=267)
pyperclip.copy("010200130001")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
time.sleep(3)
pyautogui.click(x=484, y=389)
pyautogui.click(x=449, y=387)
#Mudar hora
pyperclip.copy("0830")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.click(x=683, y=390)
pyautogui.click(x=379, y=431)
#Mudar tipos de Ordem
#pyperclip.copy("gas")
#pyautogui.hotkey("ctrl", "v")
#pyautogui.press ("tab")
#pyautogui.press ("tab")
#Ordem para inspeção é 2
pyautogui.click(x=643, y=430)
pyperclip.copy("2")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Ordem para Caleb
pyperclip.copy("65053")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Abrir OS Responsalvel Fernando
pyperclip.copy("4419")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyperclip.copy("Fazer inspeção dos cilindros de O2")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Fazer OS Para Cilindros O2
pyperclip.copy("7")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Abrir para inspeção
pyautogui.press("i")
pyautogui.press("i")
#
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Mudar Hora de Termino
pyperclip.copy("0840")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.click(x=664, y=432)
#
pyautogui.press ("tab")
pyperclip.copy("65053")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.press ("tab")
pyperclip.copy("8822")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.click(x=1068, y=644)

# %%
#Cilindro ECV

pyautogui.PAUSE = 1
time.sleep(2)
pyautogui.click(x=881, y=298)
pyautogui.click(x=403, y=267)
pyperclip.copy("010202140005")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
time.sleep(3)
pyautogui.click(x=484, y=389)
pyautogui.click(x=449, y=387)
#Mudar hora
pyperclip.copy("0840")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.click(x=683, y=390)
pyautogui.click(x=379, y=431)
#Mudar tipos de Ordem
#pyperclip.copy("gas")
#pyautogui.hotkey("ctrl", "v")
#pyautogui.press ("tab")
#pyautogui.press ("tab")
#Ordem para inspeção é 2
pyautogui.click(x=643, y=430)
pyperclip.copy("2")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Ordem para Caleb
pyperclip.copy("65053")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Abrir OS Responsalvel Fernando
pyperclip.copy("4419")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyperclip.copy("Fazer inspeção dos cilindros de O2")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Fazer OS Para Cilindros O2
pyperclip.copy("7")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Abrir para inspeção
pyautogui.press("i")
pyautogui.press("i")
#
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Mudar Hora de Termino
pyperclip.copy("0850")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.click(x=664, y=432)
#
pyautogui.press ("tab")
pyperclip.copy("65053")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.press ("tab")
pyperclip.copy("8822")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.click(x=1068, y=644)

# %%
# NO break Neuto

pyautogui.PAUSE = 1
time.sleep(2)
pyautogui.click(x=881, y=298)
pyautogui.click(x=403, y=267)
pyperclip.copy("010201140002")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
time.sleep(3)
pyautogui.click(x=484, y=389)
pyautogui.click(x=449, y=387)
#Mudar hora
pyperclip.copy("0850")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.click(x=683, y=390)
pyautogui.click(x=379, y=431)
#Mudar tipos de Ordem2
pyautogui.click(x=379, y=431)
pyautogui.click(x=379, y=431)
pyperclip.copy("ele")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Ordem para inspeção é 2
pyautogui.click(x=643, y=430)
pyperclip.copy("2")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Ordem para Caleb
pyperclip.copy("65053")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Abrir OS Responsalvel Fernando
pyperclip.copy("4419")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyperclip.copy("Fazer inspeção de No break")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Fazer OS Para Cilindros O2
pyperclip.copy("175")
pyautogui.hotkey("ctrl", "v")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Abrir para inspeção
pyautogui.press("i")
pyautogui.press("i")
#
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
pyautogui.press ("tab")
#Mudar Hora de Ter010200320001
010200120001
010201250016
010201140002
6225
6225
mino
pyperclip.copy("0900")0810

pyautogui.hotkey("ctrl","0800
               gas2650534419Fazer2650534419Fazer650534419Fazer650534419665053
                     5053650534419Fazer65053441965053650534419Fazer inspeção dos cilidros de O27ii0750650537ii0800ii0800ii0810ii0800ii0810ii0820
                 v")
pyautogui.press("enter")0750
gas2650534419Fazer2650534419Fazer650534419Fazer65053441965053
                     8822
                 Fazer inspeção dos cilidros de O27ii0750650537ii0800ii0800ii0810
                 
pyautogui.click(x=664, y=0740
               gas2650534419Fazer2650534419Fazer inspeçã65053
                    8822
                o dos cilidros de O27ii0750650537ii0800
                432)
#0730
gas2650534419Fazer inspeção dos cilidros de O27ii075065053
    8822
    

pyautogui.press ("tab")0720
ele2650534419Fazer inspeção nos Nobreaks175ii074065053
    8822
    

pyperclip.copy("65053")
pyautogui.hotkey("ctrl","v")2650534419Fazer inspeção No 65053
    8822
    Boiler215ii0730

pyautogui.press("enter")
pyautogui.press ("tab")
pyperclip.copy("8822")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.click(x=1068, y=644)

# %%
time.sleep(5)
pyautogui.position()
